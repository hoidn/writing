# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ldos_Mg = np.genfromtxt('ldos_Mg.dat')
ldos_O = np.genfromtxt('ldos_O.dat')

# %%
# Fermi level: -5.535 eV

# %%
def plot_orbital(dos, norbital, Ef)
# Out:
# array([[ -1.00000000e+02,   1.41653300e-03,   5.55835700e-04,
#           2.15136600e-04,   1.92248300e-04],
#        [ -9.94987000e+01,   1.51110400e-03,   5.65857600e-04,
#           2.16708800e-04,   1.93399200e-04],
#        [ -9.89975000e+01,   1.61576100e-03,   5.76183400e-04,
#           2.18301400e-04,   1.94562500e-04],
#        ...,
#        [  9.89975000e+01,   1.42541500e-02,   4.63267100e-02,
#           1.02775200e-01,   1.39606300e-01],
#        [  9.94987000e+01,   1.44727800e-02,   4.61577100e-02,
#           1.03023800e-01,   1.38626100e-01],
#        [  1.00000000e+02,   1.47239700e-02,   4.60729000e-02,
#           1.03402700e-01,   1.37691500e-01]])

# %%
E, s, p, d, f = ldos_Mg.T
plt.plot(E, s)
plt.plot(E, p)
plt.plot(E, d)
# Out:
# <img src="data:image/png;base64,...">

# %%
E, s, p, d, f = ldos_O.T
plt.plot(E, s)
plt.plot(E, p)
plt.plot(E, d)
# Out:
# <img src="data:image/png;base64,...">
